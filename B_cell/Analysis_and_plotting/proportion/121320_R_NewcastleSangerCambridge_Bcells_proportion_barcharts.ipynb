# %%
library(dplyr)
library(reshape2)
library(ggplot2)
library(ktplots)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
setwd('/lustre/scratch117/cellgen/team297/kt16/newcastle_covid')

# %%
bcells <- read.csv('h5ad/combined_dec_bcells_obs.csv', header= TRUE, row.names = 1)
head(bcells)
# Out:
#                           sample_id     n_genes n_genes_by_counts total_counts
# BGCV01_AAACCTGAGATGCGAC-1 BGCV01_CV0904 1986    1986              10695
# BGCV01_AAACCTGAGGGCATGT-1 BGCV01_CV0902  982     982               3053
# BGCV01_AAACCTGCATAAAGGT-1 BGCV01_CV0904 1148    1148               3882
# BGCV01_AAACCTGGTAGTACCT-1 BGCV01_CV0904 1246    1246               4421
# BGCV01_AAACGGGGTCACAAGG-1 BGCV01_CV0904 1277    1277               4003
# BGCV01_AAACGGGTCCGTCAAA-1 BGCV01_CV0904 1255    1255               5014
#                           total_counts_mt pct_counts_mt leiden
# BGCV01_AAACCTGAGATGCGAC-1 499             4.665731      11
# BGCV01_AAACCTGAGGGCATGT-1 148             4.847691      23
# BGCV01_AAACCTGCATAAAGGT-1 260             6.697579      23
# BGCV01_AAACCTGGTAGTACCT-1 187             4.229812       5
# BGCV01_AAACGGGGTCACAAGG-1 215             5.370972      23
# BGCV01_AAACGGGTCCGTCAAA-1 150             2.991623      11
#                           initial_clustering Resample Collection_Day ⋯
# BGCV01_AAACCTGAGATGCGAC-1 B_cell             Initial  D0             ⋯
# BGCV01_AAACCTGAGGGCATGT-1 B_cell             Initial  D0             ⋯
# BGCV01_AAACCTGCATAAAGGT-1 B_cell             Initial  D0             ⋯
# BGCV01_AAACCTGGTAGTACCT-1 B_cell             Initial  D0             ⋯
# BGCV01_AAACGGGGTCACAAGG-1 B_cell             Initial  D0             ⋯
# BGCV01_AAACGGGTCCGTCAAA-1 B_cell             Initial  D0             ⋯
#                           filter_bcr_quality filter_bcr_heavy filter_bcr_light
# BGCV01_AAACCTGAGATGCGAC-1 False              False            True
# BGCV01_AAACCTGAGGGCATGT-1 False              False            True
# BGCV01_AAACCTGCATAAAGGT-1 False              False            True
# BGCV01_AAACCTGGTAGTACCT-1 False              False            True
# BGCV01_AAACGGGGTCACAAGG-1 False              False            False
# BGCV01_AAACGGGTCCGTCAAA-1 False              False            False
#                           bcr_QC_pass filter_bcr initial_clustering_B leiden_B
# BGCV01_AAACCTGAGATGCGAC-1 False       True       B_cell               4
# BGCV01_AAACCTGAGGGCATGT-1 False       True       B_cell               0
# BGCV01_AAACCTGCATAAAGGT-1 False       True       B_cell               7
# BGCV01_AAACCTGGTAGTACCT-1 False       True       B_cell               0
# BGCV01_AAACGGGGTCACAAGG-1 True        False      B_cell               1
# BGCV01_AAACGGGTCCGTCAAA-1 True        False      B_cell               2
#                           leiden_B2 celltype_B            celltype_B_v2
# BGCV01_AAACCTGAGATGCGAC-1 4,1       B_non-switched_memory B_non-switched_memory
# BGCV01_AAACCTGAGGGCATGT-1 0         B_naive               B_naive
# BGCV01_AAACCTGCATAAAGGT-1 7         B_naive               B_naive
# BGCV01_AAACCTGGTAGTACCT-1 0         B_naive               B_naive
# BGCV01_AAACGGGGTCACAAGG-1 1         B_naive               B_naive
# BGCV01_AAACGGGTCCGTCAAA-1 2         B_naive               B_naive

# %%
df<- bcells %>%
  group_by(patient_id, Status_on_day_collection_summary, celltype_B) %>%
  summarise(total = n())%>%
  mutate(freq = total / sum(total))

colnames(df)<-c("patient_id", "diagnosis","celltype", "total", "freq")
# Out:
# `summarise()` regrouping output by 'patient_id', 'Status_on_day_collection_summary' (override with `.groups` argument)

# %%
df<-df %>% group_by(diagnosis, celltype) %>% summarise(mean = mean(freq))
# Out:
# `summarise()` regrouping output by 'diagnosis' (override with `.groups` argument)

# %%
df$diagnosis <- factor(df$diagnosis, levels = c("Healthy", "Asymptomatic", "Mild", "Moderate", "Severe", "Critical", "Non_covid", "LPS"))
df$celltype <- factor(df$celltype, levels = rev(c("B_immature", "B_naive", "B_non-switched_memory","B_switched_memory", "B_exhausted", 'Plasmablast', 'Plasma_cell_IgM', 'Plasma_cell_IgA', 'Plasma_cell_IgG')))

# %%
options(repr.plot.width=20, repr.plot.height=10)
g <- ggplot(df, aes(x=diagnosis, y = mean, fill=celltype))+ 
    geom_bar(position="fill", stat="identity", width = 0.8, colour = "black", size=0.2)+
      theme(aspect.ratio = 2/3)+ 
      theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1, size = 20)) +
theme(axis.text.y = element_text(size = 20)) +
theme(axis.title.x=element_blank(), axis.title.y=element_blank())+
theme(legend.text = element_text(size = 20)) +
scale_fill_manual(values = rev(c('#ade8f4', '#0077b6', '#90be6d', '#43aa8b', '#fcbf49', '#49006a','#ae017e', '#fa9fb5', '#d4b9da')))+ 
theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black")) + small_legend(keysize = .8)
g
# Out:
# plot without title

# %%
df <- bcells %>% 
  group_by(patient_id, Status_on_day_collection_summary, celltype_B) %>%
  summarise(total = n()) %>% mutate(freq = total / sum(total))
df
# Out:
# `summarise()` regrouping output by 'patient_id', 'Status_on_day_collection_summary' (override with `.groups` argument)
#     patient_id Status_on_day_collection_summary celltype_B            total
# 1   AP1        Severe                           B_exhausted             3
# 2   AP1        Severe                           B_immature             10
# 3   AP1        Severe                           B_naive               101
# 4   AP1        Severe                           B_non-switched_memory   8
# 5   AP1        Severe                           B_switched_memory      26
# 6   AP1        Severe                           Plasma_cell_IgA        25
# 7   AP1        Severe                           Plasma_cell_IgG        27
# 8   AP1        Severe                           Plasma_cell_IgM        10
# 9   AP1        Severe                           Plasmablast             5
# 10  AP10       Mild                             B_exhausted            44
# 11  AP10       Mild                             B_immature             42
# 12  AP10       Mild                             B_naive               292
# 13  AP10       Mild                             B_non-switched_memory  31
# 14  AP10       Mild                             B_switched_memory      15
# 15  AP10       Mild                             Plasma_cell_IgA        61
# 16  AP10       Mild                             Plasma_cell_IgG        71
# 17  AP10       Mild                             Plasma_cell_IgM        12
# 18  AP10       Mild                             Plasmablast            15
# 19  AP11       Mild                             B_exhausted            27
# 20  AP11       Mild                             B_immature             48
# 21  AP11       Mild                             B_naive               352
# 22  AP11       Mild                             B_non-switched_memory  39
# 23  AP11       Mild                             B_switched_memory      62
# 24  AP11       Mild                             Plasma_cell_IgA        49
# 25  AP11       Mild                             Plasma_cell_IgG        35
# 26  AP11       Mild                             Plasma_cell_IgM         6
# 27  AP11       Mild                             Plasmablast            15
# 28  AP12       Critical                         B_exhausted            54
# 29  AP12       Critical                         B_immature            160
# 30  AP12       Critical                         B_naive               984
# ⋮   ⋮          ⋮                                ⋮                     ⋮
# 970 IVLPS-2    LPS                              Plasma_cell_IgA          6
# 971 IVLPS-2    LPS                              Plasma_cell_IgG          9
# 972 IVLPS-2    LPS                              Plasma_cell_IgM          2
# 973 IVLPS-2    LPS                              Plasmablast              4
# 974 IVLPS-3    LPS                              B_exhausted              4
# 975 IVLPS-3    LPS                              B_immature              42
# 976 IVLPS-3    LPS                              B_naive                189
# 977 IVLPS-3    LPS                              B_non-switched_memory   10
# 978 IVLPS-3    LPS                              B_switched_memory       43
# 979 IVLPS-3    LPS                              Plasma_cell_IgA          3
# 980 IVLPS-3    LPS                              Plasma_cell_IgG          2
# 981 IVLPS-3    LPS                              Plasma_cell_IgM          1
# 982 IVLPS-3    LPS                              Plasmablast              1
# 983 IVLPS-4    LPS                              B_immature              11
# 984 IVLPS-4    LPS                              B_naive                 79
# 985 IVLPS-4    LPS                              B_non-switched_memory    3
# 986 IVLPS-4    LPS                              B_switched_memory       12
# 987 IVLPS-4    LPS                              Plasma_cell_IgA         12
# 988 IVLPS-4    LPS                              Plasma_cell_IgG          1
# 989 IVLPS-4    LPS                              Plasma_cell_IgM          1
# 990 IVLPS-4    LPS                              Plasmablast              4
# 991 IVLPS-6    LPS                              B_exhausted             46
# 992 IVLPS-6    LPS                              B_immature             210
# 993 IVLPS-6    LPS                              B_naive               1079
# 994 IVLPS-6    LPS                              B_non-switched_memory   69
# 995 IVLPS-6    LPS                              B_switched_memory      190
# 996 IVLPS-6    LPS                              Plasma_cell_IgA         34
# 997 IVLPS-6    LPS                              Plasma_cell_IgG         41
# 998 IVLPS-6    LPS                              Plasma_cell_IgM         20
# 999 IVLPS-6    LPS                              Plasmablast             33
#     freq
# 1   0.013953488
# 2   0.046511628
# 3   0.469767442
# 4   0.037209302
# 5   0.120930233
# 6   0.116279070
# 7   0.125581395
# 8   0.046511628
# 9   0.023255814
# 10  0.075471698
# 11  0.072041166
# 12  0.500857633
# 13  0.053173242
# 14  0.025728988
# 15  0.104631218
# 16  0.121783877
# 17  0.020583190
# 18  0.025728988
# 19  0.042654028
# 20  0.075829384
# 21  0.556082148
# 22  0.061611374
# 23  0.097946288
# 24  0.077409163
# 25  0.055292259
# 26  0.009478673
# 27  0.023696682
# 28  0.039045553
# 29  0.115690528
# 30  0.711496746
# ⋮   ⋮
# 970 0.011472275
# 971 0.017208413
# 972 0.003824092
# 973 0.007648184
# 974 0.013559322
# 975 0.142372881
# 976 0.640677966
# 977 0.033898305
# 978 0.145762712
# 979 0.010169492
# 980 0.006779661
# 981 0.003389831
# 982 0.003389831
# 983 0.089430894
# 984 0.642276423
# 985 0.024390244
# 986 0.097560976
# 987 0.097560976
# 988 0.008130081
# 989 0.008130081
# 990 0.032520325
# 991 0.026713124
# 992 0.121951220
# 993 0.626596980
# 994 0.040069686
# 995 0.110336818
# 996 0.019744483
# 997 0.023809524
# 998 0.011614402
# 999 0.019163763

# %%
write.csv(df, 'other_analyses/all_B_cell_proportions.csv')

# %%
kelvinny::dirCreate('figures/barcharts')
ggsave('figures/barcharts/bcell_prop.pdf', plot = g, h = 7, w = 7)

# %%
## for isotypes
bcells <- read.csv('h5ad/combined_dec_bcells_obs_vdj.csv', header= TRUE, row.names = 1)
df <- bcells %>% filter(celltype_B_v2 %in% c('Plasmablast', 'Plasma_cell')) %>% filter(isotype %in% c('IgM', 'IgD', 'IgA', 'IgE', 'IgG'))  %>%
  group_by(patient_id, Status_on_day_collection_summary, isotype) %>%
  summarise(total = n())%>%
  mutate(freq = total / sum(total))

colnames(df)<-c("patient_id", "diagnosis","isotype", "total", "freq")
# Out:
# `summarise()` regrouping output by 'patient_id', 'Status_on_day_collection_summary' (override with `.groups` argument)

# %%
df<-df %>% group_by(diagnosis, isotype) %>% summarise(mean = mean(freq))
# Out:
# `summarise()` regrouping output by 'diagnosis' (override with `.groups` argument)

# %%
df$diagnosis <- factor(df$diagnosis, levels = c("Healthy", "Asymptomatic", "Mild", "Moderate", "Severe", "Critical", "Non_covid", "LPS"))
df$isotype <- factor(df$isotype, levels = rev(c('IgM', 'IgD', 'IgA', 'IgE', 'IgG')))

# %%
options(repr.plot.width=20, repr.plot.height=10)
g <- ggplot(df, aes(x=diagnosis, y = mean, fill=isotype))+ 
    geom_bar(position="fill", stat="identity", width = 0.8, colour = "black", size=0.2)+
      theme(aspect.ratio = 2/3)+ 
      theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1, size = 20)) +
theme(axis.text.y = element_text(size = 20)) +
theme(axis.title.x=element_blank(), axis.title.y=element_blank())+
theme(legend.text = element_text(size = 20)) +
scale_fill_manual(values = rev(c('#264653', '#2A9D8F', '#E9C369', '#EE8959', '#D7431D')))+ 
theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black")) + small_legend(keysize = .8)
g
# Out:
# plot without title

# %%
ggsave('figures/barcharts/plasmacell_isotype_prop.pdf', plot = g, h = 7, w = 4)

# %%
sessionInfo()
# Out:
# R version 3.6.1 (2019-07-05)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /nfs/users/nfs_k/kt16/miniconda2/envs/dandelion/lib/R/lib/libRblas.so
#
# locale:
# [1] en_GB.utf8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] ktplots_1.1.7  ggplot2_3.3.2  reshape2_1.4.4 dplyr_1.0.0
#
# loaded via a namespace (and not attached):
#  [1] bitops_1.0-6                matrixStats_0.57.0
#  [3] fs_1.5.0                    doMC_1.3.7
#  [5] usethis_1.6.3               devtools_2.3.2
#  [7] RColorBrewer_1.1-2          rprojroot_1.3-2
#  [9] GenomeInfoDb_1.22.1         repr_1.1.0
# [11] tools_3.6.1                 backports_1.2.0
# [13] R6_2.5.0                    BiocGenerics_0.32.0
# [15] colorspace_1.4-1            withr_2.3.0
# [17] tidyselect_1.1.0            gridExtra_2.3
# [19] prettyunits_1.1.1           processx_3.4.4
# [21] compiler_3.6.1              glmnet_4.0-2
# [23] cli_2.1.0                   Biobase_2.46.0
# [25] Cairo_1.5-10                desc_1.2.0
# [27] DelayedArray_0.12.3         labeling_0.4.2
# [29] scales_1.1.1                callr_3.5.1
# [31] pbdZMQ_0.3-3                stringr_1.4.0
# [33] digest_0.6.27               XVector_0.26.0
# [35] base64enc_0.1-3             pkgconfig_2.0.3
# [37] htmltools_0.5.0             sessioninfo_1.1.1
# [39] rlang_0.4.6                 shape_1.4.5
# [41] farver_2.0.3                generics_0.0.2
# [43] jsonlite_1.7.1              BiocParallel_1.20.1
# [45] gtools_3.8.1                RCurl_1.98-1.2
# [47] magrittr_1.5                GenomeInfoDbData_1.2.2
# [49] patchwork_1.0.1.9000        Matrix_1.2-18
# [51] Rcpp_1.0.5                  IRkernel_1.1
# [53] munsell_0.5.0               S4Vectors_0.24.4
# [55] fansi_0.4.1                 viridis_0.5.1
# [57] lifecycle_0.2.0             stringi_1.4.3
# [59] kelvinny_2.0.5              SummarizedExperiment_1.16.1
# [61] zlibbioc_1.32.0             pkgbuild_1.1.0
# [63] plyr_1.8.6                  grid_3.6.1
# [65] parallel_3.6.1              crayon_1.3.4
# [67] lattice_0.20-41             splines_3.6.1
# [69] IRdisplay_0.7.0             ps_1.4.0
# [71] pillar_1.4.6                ranger_0.12.1
# [73] GenomicRanges_1.38.0        uuid_0.1-4
# [75] codetools_0.2-17            stats4_3.6.1
# [77] pkgload_1.1.0               glue_1.4.1
# [79] evaluate_0.14               remotes_2.2.0
# [81] vctrs_0.3.1                 foreach_1.5.0
# [83] testthat_3.0.0              gtable_0.3.0
# [85] purrr_0.3.4                 assertthat_0.2.1
# [87] survival_3.2-7              viridisLite_0.3.0
# [89] pheatmap_1.0.12             SingleCellExperiment_1.8.0
# [91] tibble_3.0.2                iterators_1.0.12
# [93] memoise_1.1.0               IRanges_2.20.2
# [95] ellipsis_0.3.1
